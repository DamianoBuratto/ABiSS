# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np

# %%
x_value= ['WT', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'M10', 'M11', 'M12', 'M13', 'M14', 'M15', 'M16', 'M17', 'M18', 'M19', 'M20', 'M21', 'M22', 'M23', 'M24', 'M25']
y_value= [0.0, -0.6, 8.1, -8.2, -4.3, -6.5, 1.9, -0.4, 7.6, -16.5, -15.9, -2.3, -19.5, -16.4, -21.1, -26.9, -12.9, -26.5, -19.2, -16.7, -14.5, -13.5, -20.9, -22.1, -23.7, -25.2]
y_err= [0.4, 0.9, 0.2, 8.5, 1.5, 3.6, 2.0, 7.4, 3.9, 1.0, 6.1, 15.8, 2.2, 7.2, 3.4, 2.6, 2.5, 1.8, 3.3, 7.1, 7.5, 7.9, 3.4, 4.4, 3.5, 1.2]
color_legend= ['black', 'blue', 'red', 'blue', 'red', 'red', 'red', 'red', 'red', 'blue', 'red', 'red', 'blue', 'red', 'blue', 'blue', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'blue', 'blue']
be_unit= "KCal/mol"

plot_name="HLA RUN1 (v4)"

# %%
skip_xticks = 5
font_size=24
size = [60 for item in range(1, len(x_value))]
size.insert(0, 100)
fig = plt.figure(figsize=(18, 10))
plt.scatter(x_value, y_value, c=color_legend, s=size)

plt.errorbar(x_value, y_value, yerr=y_err, capsize=4, fmt='none', ecolor="grey", alpha=0.6, ls="-")

plt.title(plot_name, fontsize=font_size)
plt.ylabel('Binding Energy [' + be_unit + ']', fontsize=font_size)
plt.yticks(fontsize=20)
plt.xticks(rotation=80, fontsize=20)
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=skip_xticks))
plt.grid(linestyle='--', linewidth=0.5)

plt.show()
